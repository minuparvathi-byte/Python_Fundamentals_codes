# %% [markdown]
# <a href="https://colab.research.google.com/github/minuparvathi-byte/Python_Fundamentals_codes/blob/main/Student_Registration_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Case Study – Student Registration System Instructions:**
#
# **Create variables:**
#
# student_name
#
# student_age
#
# course_name
#
# course_fee
#
# Use input() function to get student details from the user.
#
# **Use type casting:**
#
# int() for student age
#
# float() for course fee
#
# **Calculate:**
#
# gst = 18% of course fee
#
# total_fee = course fee + gst
#
# **Display all student details using:**
#
# print()
#
# f-string
#
# Display datatype of important variables using:
#
# type()

# %%
#create variable:
student_name = input("Enter Student Name:")
student_age = int(input("Enter Student Age:"))
course_name = input("Enter Course Name:")
course_fee = float(input("Enter Course Fee:"))


#calculate
gst = 0.18 * course_fee
total_fee = course_fee + gst

#display all students_details
print(f"Student Name:{student_name}")
print(f"Student Age:{student_age}")
print(f"Course Name:{course_name}")
print(f"Course Fee:{course_fee}")
print(f"GST:{gst}")
print(f"Total Fee:{total_fee}")

#data types
print(type(student_name))
print(type(student_age))
print(type(course_name))
print(type(course_fee))
print(type(gst))
print(type(total_fee))
# Out:
# Enter Student Name:minu
# Enter Student Age:33
# Enter Course Name:da
# Enter Course Fee:50000.00
# Student Name:minu
# Student Age:33
# Course Name:da
# Course Fee:50000.0
# GST:9000.0
# Total Fee:59000.0
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# # **2. Case Study – Library Fine Calculator**
# Instructions:
#
# **Create variables:**
#
# student_name
#
# book_name
#
# days_late
#
# fine_per_day
#
# Use input() function to get details from the user.
#
# Use type casting:
#
# int() for days_late
#
# float() for fine_per_day
#
# **Calculate:**
#
# total_fine = days_late * fine_per_day
#
# **Display all details using:**
#
# print()
#
# f-string
#
# Display datatype of important variables using:
#
# type()

# %%
#create variables
student_name = input('Enter student name:')
book_name = input('Enter book name:')
days_late = int(input('enter days late:'))
fine_per_day = float(input('enter fine per day:'))

#calculate
total_fine = days_late * fine_per_day

#display all details
print(f"Student Name:{student_name}")
print(f"Book Name:{book_name}")
print(f"Days Late:{days_late}")
print(f"Fine Per Day:{fine_per_day}")
print(f"Total Fine:{total_fine}")

#display data types
print(type(student_name))
print(type(book_name))
print(type(days_late))
print(type(fine_per_day))
print(type(total_fine))
# Out:
# Enter student name:Minu
# Enter book name:DA
# enter days late:4
# enter fine per day:10.0
# Student Name:Minu
# Book Name:DA
# Days Late:4
# Fine Per Day:10.0
# Total Fine:40.0
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
